# %% [markdown]
# <a href="https://colab.research.google.com/github/alxiom/Basic-NLP/blob/main/NLP_07_Trend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.10.0-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 4.1 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 45.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.4)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 35.2 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 23.3 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.16-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.16 pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.10.0

# %%
from transformers import BertTokenizer, BertModel

kc_bert_sample_text = "배가 바다를 향해 떠난다"

kc_bert_tokenizer = BertTokenizer.from_pretrained("beomi/kcbert-base")
kc_bert_model = BertModel.from_pretrained("beomi/kcbert-base")
kc_bert_inputs = kc_bert_tokenizer(kc_bert_sample_text, return_tensors="pt")
kc_bert_outputs = kc_bert_model(**kc_bert_inputs)[0]  # The last hidden-state is the first element of the output tuple

print(kc_bert_tokenizer.tokenize(kc_bert_sample_text))
print(kc_bert_outputs)  # [CLS] [배가] [바다] [를] [향해] [떠난] [다] [SEP]
print(kc_bert_outputs.shape)  # batch * seq_len * hidden_dim
# Out:
# Downloading:   0%|          | 0.00/250k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/619 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at beomi/kcbert-base were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ['배가', '바다', '##를', '향해', '떠난', '##다']
# tensor([[[-0.7413,  0.2454,  1.3657,  ...,  1.0889,  0.0650, -0.0997],
#          [-0.5421,  0.1332,  0.2314,  ...,  0.4596,  0.6814, -0.4804],
#          [ 0.5392, -0.4677, -0.5115,  ...,  1.9647,  0.6628, -0.4746],
#          ...,
#          [-0.1731, -1.4767, -1.1825,  ...,  1.8214, -0.5969, -1.5926],
#          [-0.2905,  0.5789, -0.7787,  ...,  0.3394, -0.4400, -2.1748],
#          [-0.1885,  0.1925,  1.1311,  ...,  0.9547, -0.1759, -0.2544]]],
#        grad_fn=<NativeLayerNormBackward>)
# torch.Size([1, 8, 768])

# %%
from transformers import pipeline, set_seed

gpt2_sample_text = "The Manhattan bridge"

generator = pipeline("text-generation", model="gpt2")
set_seed(42)
results = generator(gpt2_sample_text, max_length=30, num_return_sequences=5)

for result in results:
    print(result["generated_text"])
    print("--")
# Out:
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Using pad_token, but it is not set yet.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The Manhattan bridge is the most significant new thing for the city, and one that has drawn an increasing number of new developers and people who have come from
# --
# The Manhattan bridge and in the Hudson River Gorge were destroyed when a small plane crashed into a pile of rocks on Tuesday, according to sources.
#
#
# --
# The Manhattan bridge was closed to traffic for several hours after a woman said a man jumped over the bridge with a crowbar. Police said all the people
# --
# The Manhattan bridge was the scene of a major incident involving a car after a car accident. There are no official reports about how it occurred.
#
#
# --
# The Manhattan bridge is closed and people are staying at hotels as well. (Photo: Reuters)
#
# BURLINGTON, Vt – Police arrested
# --

# %%
from transformers import pipeline, set_seed

gpt2_sample_text = "그리웠던 순간을 호명하며 나는 한 줌의 눈물을 불빛 속에 던져주었다."

generator = pipeline("text-generation", model="skt/kogpt2-base-v2")
set_seed(42)
results = generator(gpt2_sample_text, max_length=100, num_return_sequences=4)

for result in results:
    print(result["generated_text"])
    print("--")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Using pad_token, but it is not set yet.
# 그리웠던 순간을 호명하며 나는 한 줌의 눈물을 불빛 속에 던져주었다. 지난 주말 서울 잠실야구장. 야구장 안에는 주말 내내 야구 관련 책.드라마를 비롯해 각종 영화와 예능 프로그램들이 가득했다.
# 이날 오전 9시 반(이하 한국 시간으로 오전 9시)경 비가 내린 여의도 한강공원에는 시민들이 한가로이 모여 운동하는 모습을 볼 수 있었다.
# 김태균(43) 씨는 “아침에 일어나자마자 비가 멎는 것을 보니 한숨이
# --
# 그리웠던 순간을 호명하며 나는 한 줌의 눈물을 불빛 속에 던져주었다. 안혜진 시인은 "한 인간이 살아가는 것은 두렵지만 그 모든 것은 순진하지만 희망의 끈을 놓지 말아야 한다"(문학동네 펴냄). 안 시인의 대표작이자 한국 현대시가 지닌 독특한 문학적 위상은 여전한가 보다.
# 2만원. 이번 행사는 국내 최초로 개최되는 한·중·일·일 미술협회 공동전시회로, 아시아 11개국에서 약 100여 점의 작품이 전시된다.
# 작가 초청
# --
# 그리웠던 순간을 호명하며 나는 한 줌의 눈물을 불빛 속에 던져주었다. 새해 첫날인 5일은 전국이 대체로 흐린 가운데 새벽부터 오전 사이에 일부 지역에 비가 오겠다.
# 기상청에 따르면 오늘 우리나라는 점차 구름이 많아지겠다.
# 낮부터 서해안을 중심으로 가끔 구름이 많아지겠다.
# 서울과 경기 북부와 강원 영서북부에는 새벽까지 빗방울 떨어질 것으로 보인다.
# 아침 최저기온은 10도에서 16도로 오늘과 비슷하거나 조금 낮겠고, 낮 최고기온은
# --
# 그리웠던 순간을 호명하며 나는 한 줌의 눈물을 불빛 속에 던져주었다. 만약 그런 순간을 목격했다면 아마도 나는 나처럼 그렇게 느꼈을 거다."
# 이 모든 감정을 내 마음에 품고 있었던 사람은 나에게 그 사실을 전해주었던 것이다.
# 내가 어떤 이유에서 그런 감정이든 받아들일 수 있었던 것은 나에게서 시작되었기에 나는, 누군가 내게 그런 감정을 품고 있지 않았다면 나는 어떻게 했을까?
# 누구나 감정이든 받아들일 수 있는 사람은 있고, 다른 사람들의 감정에 대해서는 그렇게 느끼지도 않은 사람은 있다.
# 그렇
# --
